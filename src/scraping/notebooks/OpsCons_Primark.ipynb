# %%
import requests
from bs4 import BeautifulSoup as Soup
import pandas as pd
import hashlib
import datetime


def parse_sitemap( url,headers):
    # First of all we make a request to the specified url in the function parameters.
    resp = requests.get(url)
    # if we didn't get a valid response, return false 
    status = resp.status_code 
    if (status != 200):
        return False
    # Then we parse the content of the response using BeautifulSoup4.
    soup = Soup(resp.content, "xml")

    #Then we look for either a urlset or a sitemapindex
    urls = soup.findAll('url')
    sitemaps = soup.findAll('sitemap')
    #create pandas dataframe
    new_list = ["Source"] + headers
    panda_out_total = pd.DataFrame([], columns=new_list)


    if not urls and not sitemaps:
        return False

    # Recursive call to the the function if sitemap contains sitemaps
    if sitemaps:
        for url in sitemaps:
            sitemap_url = url.find('loc').string
            panda_recursive = parse_sitemap(sitemap_url, headers)
            panda_out_total = pd.concat([panda_out_total, panda_recursive], ignore_index=True)

    # storage for later...
    out = []

    # Creates a hash of the parent sitemap for faster indexing
    hash_sitemap = hashlib.md5(str(url).encode('utf-8')).hexdigest()

    # Extract the keys we want
    for u in urls:
        values = [hash_sitemap]
        for head in headers:
            loc = None
            loc = u.find(head)
            if not loc:
                loc = "None"
            else:
                loc = loc.string
            values.append(loc)
        out.append(values)
    
    # Creates a dataframe
    panda_out = pd.DataFrame(out, columns= new_list)

    # If recursive then merge recursive dataframe
    if not panda_out_total.empty:
        panda_out = pd.concat([panda_out, panda_out_total], ignore_index=True)

    #returns the dataframe
    return panda_out

# %%
# Do the web scraping for each url 

def get_product_info(results_page):

    # find product material - No product material 
    product_material = "NaN"
    
    # find product title
    title = results_page.find('h1', class_ = 'product__title')
    display_name= title.text

    # find product color
    color_span = results_page.find('span', class_ = 'product__swatch-text')
    if color_span == None:
        color = "N/A"
    else:
        color = str(color_span.text).replace(" ", "")

    # find product url 
    product_url = url 

    # find price of the product 
    price_html = results_page.find('span', class_ = 'product__price')
    price = str(price_html.text).replace(" ", "")

    #find image link
    image_link_color = []
    images_html = results_page.find('div', class_ = 'product-images')
    images = images_html.find_all('img')
    for im in images:
        image_link_color.append(im['src'])


    # find size of the product 
    sizes =  []
    size_html = results_page.find('div', class_ = 'swatch size')
    if size_html == None:
        sizes = ['N/A']
    else:
        size_elements = size_html.find_all('input')
        for product_size in size_elements:
            size = product_size['value']
            sizes.append(size)

    # find brand name 
    brand_name = "Mate the label"

    # find description
    description = results_page.find('div', class_="product-accordions__single-content", id = "product-accordions__details").text


    # alternative: use meta to locate information
    # test = results_page.find("meta", property="og:title")
    # print(test['content'])


    # find low level, if no category, set the default as product name, regex it later on
    low_level = display_name
    # default = no 
    second_hand = 'No'
    # female
    gender = "female"
    # today's date
    scrapped_date = datetime.today().strftime('%Y-%m-%d')

    new_row = {'display_name': display_name,
               'product_material': product_material,
               'color': color, 'size': size,
               'price':price, 'product_url':product_url,
               'image_link_color':image_link_color,
               'brand_name':brand_name,
               'description':description,
               'scrapped_date': scrapped_date,
               'low_level':low_level,
               'gender':gender,
               'secondhand': second_hand }

    global df
    df = df.append(new_row, ignore_index=True)

# %%
result = parse_sitemap("https://www.primark.com/en-us/sitemap.xml", ["loc"])
df = result
df = df.drop(columns='Unnamed: 0')
result_test = df
result_test

# %%
import re
product_urls = []
non_product_urls = []
df = pd.DataFrame(columns= ['id_style','display_name', 'materials', 'color', 'size', 'price', 'currency', 'product_url', 'image_links', 'brand_name', 'retailer', 'description', 'scrapped_date', 'high_level', 'low_level', 'gender', 'secondhand', 'shipping_from', 'style'])

for url in result_test[result_test.columns[0]]:
    print(type(str(url.string)))
    product = False
    response = requests.get(url)
    if response.status_code == 200:
        print("Success")
    else:
        print("Failure")
    results_page = Soup(response.content,'html')
    # Input html class selector to verify if the page is a product page
    # Refer to Category Links EXCEL for html_element and class_id
    html_element = 'button'
    class_id = 'product-panel__collapse-button js-collapse-button'
    if results_page.find(html_element, class_ = class_id) != None:
        product_urls.append(url)
        product = True
    else:
        print('hello')
        non_product_urls.append(url)

    #### if product == TRUE, then start scraping #### 

    if product ==True:

        # find product material - No product material 
        materials = "NaN"

        id_style = "NaN"
        
        # find product title
        title = results_page.find('h1', class_ = 'product-panel__name heading heading--h5')
        display_name= title.text

        # find product color
        color = "NaN"

        # find product url 
        product_url = url 

        # find price of the product 
        price_html = results_page.find('p', class_ = 'heading heading--h5')
        price= price_html.text

        # find currency
        currency = results_page.find('div', 'product-detail product-view-item')['data-currency']

        #find image link
        image_links = []
        images_html = results_page.find("meta", property="og:image")
        image_links.append(images_html['content'])

        print(image_links)
        gender = 'women'
        if 'men' in str(url):
            gender = 'men'


        category = results_page.find('div', 'product-detail product-view-item')['data-category']


        brand_name = 'Primark'
        retailer = 'Primark'
        shipping_from = 'NaN'
        high_level = "NaN"
        style = 'NaN'
        size = 'NaN'
        secondhand='No'
        scrapped_date=str(datetime.date.today())
        description = "NaN"

        new_row = {'display_name': display_name,
               'materials': materials,
               'color': color, 'size': size,
               'price':price, 'currency': currency,'product_url':product_url,
               'image_links':image_links,
               'brand_name':brand_name,
               'retailer' : retailer,
               'description':description,
               'scrapped_date': scrapped_date,
               'high_level':high_level,
               'low_level':category,
               'gender':gender,
               'secondhand': secondhand, 
               'shipping_from': shipping_from, 
               'style': style }

        global df
        df = df.append(new_row, ignore_index=True)
# Out:
# <class 'str'>
# Success
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/120905409_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Toiletries: Soaps, Scrubs & Bath Essentials
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/125272268_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Makeup Tools: Brushes, Curlers & More
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127855821_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Foundation, Concealer, Primers, Powders & More
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127855854_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Foundation, Concealer, Primers, Powders & More
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127855839_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Foundation, Concealer, Primers, Powders & More
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127647186_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Luggage & Travel Essentials
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127647194_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Luggage & Travel Essentials
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127684874_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Foundation, Concealer, Primers, Powders & More
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/124608983_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/124616093_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/128088927_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Kids Toys & Games
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127465753_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Makeup Tools: Brushes, Curlers & More
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127278503_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Phone Accessories & Tech
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127284105_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Luggage & Travel Essentials
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127346573_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Eyeshadow Palettes & Eyeliners
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127112819_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Makeup Brushes & Blenders
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/128262738_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Phone Accessories & Tech
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/128861182_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Grooming
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130600594_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Kids Toys & Games
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130505314_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Pyjamas
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130604463_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Grooming
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130626755_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Shorts
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127124756_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Grooming
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127003042_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Foundation, Concealer, Primers, Powders & More
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127007472_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Foundation, Concealer, Primers, Powders & More
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/128626858_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/128627112_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127512190_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Fragrance: Perfumes & Body Mists
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127512158_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Fragrance: Perfumes & Body Mists
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127512174_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Fragrance: Perfumes & Body Mists
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/127518692_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Fragrance: Perfumes & Body Mists
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130026329_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Phone Accessories & Tech
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130058371_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Slim Fit Jeans
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130062944_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# False Nails & Polishes
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130082306_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# False Nails & Polishes
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130101452_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
#
ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130892738_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Tops
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130910944_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130910886_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130913724_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130914185_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130914946_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130920729_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130937111_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130938044_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130938606_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130939760_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131640714_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Jeans for Women
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131774349_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Jeans for Women
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131714568_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Hoodies
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131730291_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Ballet Shoes, Loafers & Pumps
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131750455_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Throws & Blankets
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131770271_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Slippers
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131777649_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Belts
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131840710_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Jumpers & Sweaters
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131843623_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Slippers
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131843581_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Slippers
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/131866301_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Girls Dresses Age 2-7
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/129258693_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Girls Clothes Age 2-7
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/129321277_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Bathroom Accessories
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/129380737_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Shoes & Boots
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/129342208_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Short Sleeve Shirts
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/129381529_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Accessories: Belts, Hats & Sunglasses
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/129389001_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Bras
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/129425870_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Hats, Scarves & Gloves
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132264787_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Hats, Scarves & Gloves
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132226687_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Kids Accessories
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132227792_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Kids Accessories
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132237676_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Kids Accessories
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132287846_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Lipstick, Lip Glosses & Lip Liner
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132287853_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Lipstick, Lip Glosses & Lip Liner
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132338052_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Kids Accessories
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132350230_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Lingerie Coordinates
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132355478_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's T-Shirts
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132355494_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's T-Shirts
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132365162_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Socks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132365147_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Socks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132367424_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Sports Socks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132367440_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Men's Sports Socks
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130734757_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Fragrance: Perfumes & Body Mists
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130733114_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Fragrance: Perfumes & Body Mists
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130711425_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Beauty Accessories
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130531450_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Face Creams, Face Oils & Masks
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130547480_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Beauty Accessories
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130549759_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Beauty Accessories
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130671405_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# T-shirt Bras
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130671421_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# T-shirt Bras
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130673260_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Bras
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130673492_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Bras
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130685223_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Bras
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130685249_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Bralettes
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130685389_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Bras
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130691122_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Bras
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130693813_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Sunglasses
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130693805_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Sunglasses
# <class 'str'>
# Failure
# hello
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/130529926_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# men
# Women's Pyjamas
# <class 'str'>
# Success
# ['https://primedia.primark.com/s/primark/132740281_ms?locale=en-US,en-US,en-*,*&$zoom$?$poi$&w=1200&sm=aspect&aspect=1200:628']
# women
# Baby Boy Clothes

# %%
df
# Out:
#     id_style                                  display_name  ... shipping_from style
# 0        NaN             5-Pack Colorful Toothbrush Covers  ...           NaN   NaN
# 1        NaN                  15-Pack Wooden Cuticle Stick  ...           NaN   NaN
# 2        NaN                        Bake It Setting Powder  ...           NaN   NaN
# 3        NaN                        Bake It Setting Powder  ...           NaN   NaN
# 4        NaN                        Bake It Setting Powder  ...           NaN   NaN
# ..       ...                                           ...  ...           ...   ...
# 186      NaN   Dusky Pink Premium T-Shirt Bra In Sizes D-F  ...           NaN   NaN
# 187      NaN               Black Basic Button Glasses Case  ...           NaN   NaN
# 188      NaN         Beige Basic Heart Button Glasses Case  ...           NaN   NaN
# 189      NaN  Hot Pink Seamfree Lace Trim Cropped Camisole  ...           NaN   NaN
# 190      NaN    Baby Boy Orange Print Crew Neck Sweatshirt  ...           NaN   NaN
#
# [191 rows x 19 columns]

# %%
df.to_csv('primark_table.csv', sep='\t', encoding='utf-8')
from google.colab import files
files.download("primark_table.csv")
